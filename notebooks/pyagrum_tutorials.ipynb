# %%
import pyagrum as gum
import pyagrum.lib.notebook as gnb

# %%
bn = gum.BayesNet("WaterSprinkler")
print(bn)
# Out:
# BN{nodes: 0, arcs: 0, domainSize: 1, dim: 0, mem: 0o}

# %%
id_c = bn.add(gum.LabelizedVariable("c", "Cloudy", 2))
print(id_c)
print(bn.variable(id_c))
# Out:
# 0
# c:Labelized({0|1})

# %%
id_s, id_r, id_w = [
    bn.add(name,2) for name in ["s", "r", "w"]
]
print(bn)
# Out:
# BN{nodes: 4, arcs: 0, domainSize: 16, dim: 4, mem: 64o}

# %%
print(f"{bn.variable(id_s)=}")
print(f"{bn['s']=}")
print(f"{id_s=}")
print(f"{bn.idFromName('s')=}")
print(f"{bn.variable(id_s).name()=}")
# Out:
# bn.variable(id_s)=(pyagrum.DiscreteVariable@0x20227bf0) s:Range([0,1])
# bn['s']=(pyagrum.DiscreteVariable@0x20227bf0) s:Range([0,1])
# id_s=1
# bn.idFromName('s')=1
# bn.variable(id_s).name()='s'

# %%
bn.addArc(id_c, id_s)

# %%
for link in [(id_c, id_r), ("s", "w"), ("r", "w")]:
  bn.addArc(*link)
print(bn)
# Out:
# BN{nodes: 4, arcs: 4, domainSize: 16, dim: 9, mem: 144o}

# %%
bn
# Out:
# (pyagrum.BayesNet@0x201f3680) BN{nodes: 4, arcs: 4, domainSize: 16, dim: 9, mem: 144o}

# %%
bn2 = gum.fastBN("c->r->w<-s<-c", "{No|Yes}")  # by default, variable is labelized {No|Yes}
bn2
# Out:
# (pyagrum.BayesNet@0x1eefcbb0) BN{nodes: 4, arcs: 4, domainSize: 16, dim: 9, mem: 144o}

# %%
print(bn2.variable("c"))
print(bn.variable("c"))
bn = bn2
# Out:
# c:Labelized({No|Yes})
# c:Labelized({0|1})
